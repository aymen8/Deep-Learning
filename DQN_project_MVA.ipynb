# %% [markdown]
# **You may need to install [OpenCV](https://pypi.python.org/pypi/opencv-python) and [scikit-video](http://www.scikit-video.org/stable/).**

# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import skvideo.io
import cv2
import json

from keras.models import Sequential,model_from_json
from keras.layers.core import Dense
from keras.optimizers import sgd
from keras.layers import Conv2D, MaxPooling2D, Activation, AveragePooling2D,Reshape,BatchNormalization, Flatten
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # MiniProject #3: Deep Reinforcement Learning

# %% [markdown]
# __Notations__: $E_p$ is the expectation under probability $p$. Please justify each of your answer and widely comment your code.

# %% [markdown]
# # Context

# %% [markdown]
# In a reinforcement learning algorithm, we modelize each step $t$ as an action $a_t$ obtained from a state $s_t$, i.e. $\{(a_{t},s_{t})_{t\leq T}\}$ having the Markov property. We consider a discount factor $\gamma \in [0,1]$ that ensures convergence. The goal is to find among all the policies $\pi$, one that maximizes the expected reward:
#
# \begin{equation*}
# R(\pi)=\sum_{t\leq T}E_{p^{\pi}}[\gamma^t r(s_{t},a_{t})] \> ,
# \end{equation*}
#
# where:
# \begin{equation*}p^{\pi}(a_{0},a_{1},s_{1},...,a_{T},s_{T})=p(a_{0})\prod_{t=1}^{T}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# We note the $Q$-function:
#
# \begin{equation*}Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] \> .
# \end{equation*}
#
# Thus, the optimal Q function is:
# \begin{equation*}
# Q^*(s,a)=\max_{\pi}Q^\pi(s,a) \> .
# \end{equation*}
#
# In this project, we will apply the deep reinforcement learning techniques to a simple game: an agent will have to learn from scratch a policy that will permit it maximizing a reward.

# %% [markdown]
# ## The environment, the agent and the game

# %% [markdown]
# ### The environment

# %% [markdown]
# ```Environment``` is an abstract class that represents the states, rewards, and actions to obtain the new state.

# %%
class Environment(object):
    def __init__(self):
        pass

    def act(self, act):
        """
        One can act on the environment and obtain its reaction:
        - the new state
        - the reward of the new state
        - should we continue the game?

        :return: state, reward, game_over
        """
        pass


    def reset(self):
        """
        Reinitialize the environment to a random state and returns
        the original state

        :return: state
        """
        pass
    
    def draw(self):
        """
        Visualize in the console or graphically the current state
        """
        pass

# %% [markdown]
# The method ```act``` allows to act on the environment at a given state $s_t$ (stored internally), via action $a_t$. The method will return the new state $s_{t+1}$, the reward $r(s_{t},a_{t})$ and determines if $t\leq T$ (*game_over*).
#
# The method ```reset``` simply reinitializes the environment to a random state $s_0$.
#
# The method ```draw``` displays the current state $s_t$ (this is useful to check the behavior of the Agent).
#
# We modelize $s_t$ as a tensor, while $a_t$ is an integer.

# %% [markdown]
# ### The Agent

# %% [markdown]
# The goal of the ```Agent``` is to interact with the ```Environment``` by proposing actions $a_t$ obtained from a given state $s_t$ to attempt to maximize its __reward__ $r(s_t,a_t)$. We propose the following abstract class:

# %%
class Agent(object):
    def __init__(self, epsilon=0.1, n_action=4):
        self.epsilon = epsilon
        self.n_action = n_action
    
    def set_epsilon(self,e):
        self.epsilon = e

    def act(self,s,train=True):
        """ This function should return the next action to do:
        an integer between 0 and 4 (not included) with a random exploration of epsilon"""
        if train:
            if np.random.rand() <= self.epsilon:
                a = np.random.randint(0, self.n_action, size=1)[0]
            else:
                a = self.learned_act(s)
        else: # in some cases, this can improve the performance.. remove it if poor performances
            a = self.learned_act(s)

        return a

    def learned_act(self,s):
        """ Act via the policy of the agent, from a given state s
        it proposes an action a"""
        pass

    def reinforce(self, s, n_s, a, r, game_over_):
        """ This function is the core of the learning algorithm. 
        It takes as an input the current state s_, the next state n_s_
        the action a_ used to move from s_ to n_s_ and the reward r_.
        
        Its goal is to learn a policy.
        """
        pass

    def save(self):
        """ This function returns basic stats if applicable: the
        loss and/or the model"""
        pass

    def load(self):
        """ This function allows to restore a model"""
        pass

# %% [markdown]
# ***
# __Question 1__:
# Explain the function act. Why is ```epsilon``` essential?

# %% [markdown]
# The function act makes the agent chooses a random action with a probability of $\epsilon$ and a learnt action with a probability of $1-\epsilon$.
#
# The value of ```epsilon``` defines the proportion" of random actions that an agent can take. It allows discovering some new actions that an agent wouldn't have taken under a deterministic policy for example.
#
# Thus, it is essential to find an optimal value of ```epsilon``` to optimize the trade-off between learnt actions and exploration.

# %% [markdown]
# ***
# ### The Game

# %% [markdown]
# The ```Agent``` and the ```Environment``` work in an interlaced way as in the following (take some time to understand this code as it is the core of the project)
#
# ```python
#
# epoch = 300
# env = Environment()
# agent = Agent()
#
#
# # Number of won games
# score = 0
# loss = 0
#
#
# for e in range(epoch):
#     # At each epoch, we restart to a fresh game and get the initial state
#     state = env.reset()
#     # This assumes that the games will end
#     game_over = False
#
#     win = 0
#     lose = 0
#
#     while not game_over:
#         # The agent performs an action
#         action = agent.act(state)
#
#         # Apply an action to the environment, get the next state, the reward
#         # and if the games end
#         prev_state = state
#         state, reward, game_over = env.act(action)
#
#         # Update the counters
#         if reward > 0:
#             win = win + reward
#         if reward < 0:
#             lose = lose -reward
#
#         # Apply the reinforcement strategy
#         loss = agent.reinforce(prev_state, state,  action, reward, game_over)
#
#     # Save as a mp4
#     if e % 10 == 0:
#         env.draw(e)
#
#     # Update stats
#     score += win-lose
#
#     print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
#           .format(e, epoch, loss, win, lose, win-lose))
#     agent.save()
# ```

# %% [markdown]
# # The game, *eat cheese*

# %% [markdown]
# A rat runs on an island and tries to eat as much as possible. The island is subdivided into $N\times N$ cells, in which there are cheese (+0.5) and poisonous cells (-1). The rat has a visibility of 2 cells (thus it can see $5^2$ cells). The rat is given a time $T$ to accumulate as much food as possible. It can perform 4 actions: going up, down, left, right.
#
# The goal is to code an agent to solve this task that will learn by trial and error. We propose the following environment:

# %%
class Environment(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)
        
        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %% [markdown]
# The following elements are important because they correspond to the hyper parameters for this project:

# %%
# parameters
size = 13
T=200
temperature=0.3
epochs_train=60 # set small when debugging
epochs_test=20 # set small when debugging

# display videos
def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))

# %% [markdown]
# __Question 2__ Explain the use of the arrays ```position``` and ```board```.

# %% [markdown]
# The array ```position``` is a matrix that defines the positions where the agent is, and where he can or can't go. Here we give the value of 1 for the position of the rat, 0 for a position he can go and -1 for a position he can't go to.
#
# The array ```board``` is a matrix that contains the reward of being on each position of the board here -1 for poison, 0.5 for cheese and 0 for nothing or if the rat already took the cheese or the poison.

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ***
# __Question 3__ Implement a random Agent (only ```learned_act``` needs to be implemented):

# %%
class RandomAgent(Agent):
    def __init__(self):
        super(RandomAgent, self).__init__()
        pass

    def learned_act(self, s):
        return np.random.randint(self.n_action)

# %% [markdown]
# ***
# ***
# __Question 4__ Visualize the game moves. You need to fill in the following function for the evaluation:

# %%
def test(agent,env,epochs,prefix=''):
    # Number of won games
    score = 0
        
    for e in range(epochs):
        state = env.reset()
        game_over = False
        win, lose = (0, 0)        
        while not game_over:
            action = agent.act(state)
            state, reward, game_over = env.act(action)
            if reward > 0:
                win += reward
            if reward < 0:
                lose -= reward
        # Save as a mp4
        env.draw(prefix+str(e))
        # Update stats
        score = score + win - lose

        print("Win/lose count {}/{}. Average score ({})"
              .format(win, lose, score/(1+e)))
    print('Final score: '+str(score/epochs))

# %%
# Initialize the game
env = Environment(grid_size=size, max_time=T,temperature=temperature)

# Initialize the agent!
agent = RandomAgent()

test(agent,env,epochs_test,prefix='random')
HTML(display_videos('random19.mp4'))
# Out:
# Win/lose count 9.5/17.0. Average score (-7.5)
# Win/lose count 5.5/16.0. Average score (-9.0)
# Win/lose count 10.5/8.0. Average score (-5.166666666666667)
# Win/lose count 10.0/15.0. Average score (-5.125)
# Win/lose count 6.5/10.0. Average score (-4.8)
# Win/lose count 14.0/16.0. Average score (-4.333333333333333)
# Win/lose count 9.5/18.0. Average score (-4.928571428571429)
# Win/lose count 9.0/20.0. Average score (-5.6875)
# Win/lose count 9.5/13.0. Average score (-5.444444444444445)
# Win/lose count 9.0/12.0. Average score (-5.2)
# Win/lose count 10.5/16.0. Average score (-5.2272727272727275)
# Win/lose count 9.5/12.0. Average score (-5.0)
# Win/lose count 6.0/10.0. Average score (-4.923076923076923)
# Win/lose count 11.0/12.0. Average score (-4.642857142857143)
# Win/lose count 11.5/15.0. Average score (-4.566666666666666)
# Win/lose count 11.0/16.0. Average score (-4.59375)
# Win/lose count 13.0/11.0. Average score (-4.205882352941177)
# Win/lose count 13.5/15.0. Average score (-4.055555555555555)
# Win/lose count 7.0/9.0. Average score (-3.9473684210526314)
# Win/lose count 11.0/11.0. Average score (-3.75)
# Final score: -3.75
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ## DQN

# %% [markdown]
# Let us assume here that $T=\infty$.
#
# ***
# __Question 5__ Let $\pi$ be a policy, show that:
#
# \begin{equation*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:
#
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
# Finally, deduce that a plausible objective is:
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# Lets show that $ Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')] $:
#
# \begin{align*}
# Q^\pi(s,a)&=E_{p^{\pi}}[\sum_{t=0}^{\infty}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a]\\
#           &=E_{p^{\pi}}[r(s_0,a_0) + \gamma\sum_{t=1}^{\infty}\gamma^{t-1}r(s_{t},a_{t})|s_{0}=s,a_{0}=a]\\
#           &=r(s,a) + \gamma E_{p^{\pi}}[\sum_{t=0}^{\infty}\gamma^{t}r(s_{t+1},a_{t+1})|s_{0}=s,a_{0}=a]\\
#           &=r(s,a) + E_{(s',a')\sim p(.|s,a)}\left(\gamma E_{p^{\pi}}[\sum_{t=0}^{\infty}\gamma^{t}r(s_{t},a_{t})|s_{0}=s',a_{0}=a']\right)\\
#           &=E_{(s',a')\sim p(.|s,a)}\left(r(s,a) + \gamma E_{p^{\pi}}[\sum_{t=0}^{\infty}\gamma^{t}r(s_{t},a_{t})|s_{0}=s',a_{0}=a']\right)\\
# Q^\pi(s,a)&=E_{(s',a')\sim p(.|s,a)}\left(r(s,a) + \gamma Q^{\pi}(s',a') \right)
# \end{align*}
#
# Now lets show that $Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')]$:
#
# First we have that $\pi^*(s')= arg\max_{a'} Q^{*}(s',a')$
#
# \begin{align*}
# Q^*(s,a)&= E_{(s',a')\sim p(.|s,a)}\left(r(s,a) + \gamma Q^{*}(s',a') \right)\\
#         &= E_{(s',a')\sim p(.|s,a)\\a'\sim \pi^*(.|s')}\left(r(s,a) + \gamma Q^{*}(s',a') \right)\\
# Q^*(s,a)&= E_{s' \sim \pi^*(.|s,a)}\left(r(s,a) + \gamma \max_{a'}Q^{*}(s',a') \right)\\
# \end{align*}
#
# Finally lets show that $\mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}$:
#
# Based on the previous relations $Q^*$ is a solution of the equation $F(Q) = E_{s' \sim \pi^*(.|s,a)}\left(r(s,a) + \gamma \max_{a'}Q(s',a') - Q(s,a)\right) = 0$
#
# Thus, by minimizing $\mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}$ we will get the optimal $Q$.

# %% [markdown]
# ***
# The DQN-learning algorithm relies on these derivations to train the parameters $\theta$ of a Deep Neural Network:
#
# 1. At the state $s_t$, select the action $a_t$ with best reward using $Q_t$ and store the results;
#
# 2. Obtain the new state $s_{t+1}$ from the environment $p$;
#
# 3. Store $(s_t,a_t,s_{t+1})$;
#
# 4. Obtain $Q_{t+1}$ by minimizing  $\mathcal{L}$ from a recovered batch from the previously stored results.
#
# ***
# __Question 6__ Implement the class ```Memory``` that stores moves (in a replay buffer) via ```remember``` and provides a ```random_access``` to these. Specify a maximum memory size to avoid side effects. You can for example use a ```list()``` and set by default ```max_memory=100```.

# %%
class Memory(object):
    def __init__(self, max_memory=100):
        self.max_memory = max_memory
        self.memory = list()

    def remember(self, m):
        if len(self.memory)>=self.max_memory:
            self.memory.pop(0)
        self.memory.append(m)
        
    def random_access(self):
        return self.memory[np.random.randint(len(self.memory))]

# %% [markdown]
# ***
# The pipeline we will use for training is given below:

# %%
def train(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %% [markdown]
# ***
# __Question 7__ Implement the DQN training algorithm using a cascade of fully connected layers. You can use different learning rate, batch size or memory size parameters. In particular, the loss might oscillate while the player will start to win the games. You have to find a good criterium.

# %%
class DQN(Agent):
    def __init__(self, grid_size,  epsilon = 0.1, memory_size=100, batch_size = 16,n_state=2):
        super(DQN, self).__init__(epsilon = epsilon)

        # Discount for Q learning
        self.discount = 0.99
        
        self.grid_size = grid_size
        
        # number of state
        self.n_state = n_state

        # Memory
        self.memory = Memory(memory_size)
        
        # Batch size when learning
        self.batch_size = batch_size

    def learned_act(self, s):
        return np.argmax(self.model.predict(s[None]),1)

    def reinforce(self, s_, n_s_, a_, r_, game_over_):
        # Two steps: first memorize the states, second learn from the pool

        self.memory.remember([s_, n_s_, a_, r_, game_over_])
        
        input_states = np.zeros((self.batch_size, 5,5,self.n_state))
        target_q = np.zeros((self.batch_size, 4))
        
        for i in range(self.batch_size):
            s_, n_s_, a_, r_, game_over_ = self.memory.random_access()
            input_states[i] = s_
            
            target_q[i] = self.model.predict(s_[None])
            
            if game_over_:
                target_q[i,a_] = r_
            else:
                target_q[i,a_] = r_ + self.discount * np.max(self.model.predict(n_s_[None]), axis=1)
        # HINT: Clip the target to avoid exploiding gradients.. -- clipping is a bit tighter
        target_q = np.clip(target_q, -3, 3)
        l = self.model.train_on_batch(input_states, target_q)
        return l

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        model.compile("sgd", "mse")
        self.model = model

            
class DQN_FC(DQN):
    def __init__(self, *args, lr=0.1,**kwargs):
        super(DQN_FC, self).__init__( *args,**kwargs)
        
        # NN Model        
        model = Sequential()
        model.add(Flatten(input_shape=(5, 5, self.n_state)))
        model.add(Dense(20, activation='relu'))
        model.add(Dense(8, activation='relu'))
        model.add(Dense(4))
        
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent, env, epochs_train, prefix='fc_train')
HTML(display_videos('fc_train50.mp4'))
# Out:
# Epoch 000/060 | Loss 0.0016 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 001/060 | Loss 0.0070 | Win/lose count 2.5/0 (2.5)
# Epoch 002/060 | Loss 0.0100 | Win/lose count 1.5/1.0 (0.5)
# Epoch 003/060 | Loss 0.0009 | Win/lose count 3.5/5.0 (-1.5)
# Epoch 004/060 | Loss 0.0736 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 005/060 | Loss 0.1462 | Win/lose count 5.0/2.0 (3.0)
# Epoch 006/060 | Loss 0.0035 | Win/lose count 4.0/3.0 (1.0)
# Epoch 007/060 | Loss 0.0021 | Win/lose count 5.5/2.0 (3.5)
# Epoch 008/060 | Loss 0.0054 | Win/lose count 3.0/0 (3.0)
# Epoch 009/060 | Loss 0.0398 | Win/lose count 2.0/2.0 (0.0)
# Epoch 010/060 | Loss 0.0295 | Win/lose count 4.0/7.0 (-3.0)
# Epoch 011/060 | Loss 0.0049 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 012/060 | Loss 0.0496 | Win/lose count 3.5/6.0 (-2.5)
# Epoch 013/060 | Loss 0.0023 | Win/lose count 4.5/3.0 (1.5)
# Epoch 014/060 | Loss 0.0014 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 015/060 | Loss 0.0032 | Win/lose count 3.0/1.0 (2.0)
# Epoch 016/060 | Loss 0.0072 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 017/060 | Loss 0.0080 | Win/lose count 4.5/3.0 (1.5)
# Epoch 018/060 | Loss 0.0061 | Win/lose count 8.5/7.0 (1.5)
# Epoch 019/060 | Loss 0.0078 | Win/lose count 2.5/2.0 (0.5)
# Epoch 020/060 | Loss 0.0081 | Win/lose count 0.5/3.0 (-2.5)
# Epoch 021/060 | Loss 0.0018 | Win/lose count 6.5/1.0 (5.5)
# Epoch 022/060 | Loss 0.0045 | Win/lose count 5.0/6.0 (-1.0)
# Epoch 023/060 | Loss 0.0073 | Win/lose count 7.0/4.0 (3.0)
# Epoch 024/060 | Loss 0.0044 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 025/060 | Loss 0.0035 | Win/lose count 4.0/5.0 (-1.0)
# Epoch 026/060 | Loss 0.0049 | Win/lose count 5.5/1.0 (4.5)
# Epoch 027/060 | Loss 0.0093 | Win/lose count 5.5/2.0 (3.5)
# Epoch 028/060 | Loss 0.0439 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 029/060 | Loss 0.0434 | Win/lose count 2.0/1.0 (1.0)
# Epoch 030/060 | Loss 0.0030 | Win/lose count 5.5/8.0 (-2.5)
# Epoch 031/060 | Loss 0.0546 | Win/lose count 9.0/6.0 (3.0)
# Epoch 032/060 | Loss 0.0031 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 033/060 | Loss 0.0021 | Win/lose count 3.0/2.0 (1.0)
# Epoch 034/060 | Loss 0.0357 | Win/lose count 4.0/3.0 (1.0)
# Epoch 035/060 | Loss 0.0032 | Win/lose count 7.0/3.0 (4.0)
# Epoch 036/060 | Loss 0.0082 | Win/lose count 7.0/2.0 (5.0)
# Epoch 037/060 | Loss 0.0408 | Win/lose count 4.0/4.0 (0.0)
# Epoch 038/060 | Loss 0.0045 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 039/060 | Loss 0.0017 | Win/lose count 3.5/2.0 (1.5)
# Epoch 040/060 | Loss 0.0366 | Win/lose count 4.0/0 (4.0)
# Epoch 041/060 | Loss 0.0063 | Win/lose count 7.0/4.0 (3.0)
# Epoch 042/060 | Loss 0.0485 | Win/lose count 2.5/2.0 (0.5)
# Epoch 043/060 | Loss 0.0028 | Win/lose count 9.5/1.0 (8.5)
# Epoch 044/060 | Loss 0.0066 | Win/lose count 11.0/5.0 (6.0)
# Epoch 045/060 | Loss 0.0066 | Win/lose count 6.5/1.0 (5.5)
# Epoch 046/060 | Loss 0.0053 | Win/lose count 6.5/3.0 (3.5)
# Epoch 047/060 | Loss 0.0036 | Win/lose count 8.0/2.0 (6.0)
# Epoch 048/060 | Loss 0.0035 | Win/lose count 9.0/2.0 (7.0)
# Epoch 049/060 | Loss 0.0148 | Win/lose count 7.0/2.0 (5.0)
# Epoch 050/060 | Loss 0.0035 | Win/lose count 4.5/1.0 (3.5)
# Epoch 051/060 | Loss 0.0040 | Win/lose count 6.5/0 (6.5)
# Epoch 052/060 | Loss 0.0397 | Win/lose count 4.0/3.0 (1.0)
# Epoch 053/060 | Loss 0.0078 | Win/lose count 4.0/0 (4.0)
# Epoch 054/060 | Loss 0.0046 | Win/lose count 3.0/1.0 (2.0)
# Epoch 055/060 | Loss 0.0038 | Win/lose count 5.0/4.0 (1.0)
# Epoch 056/060 | Loss 0.0101 | Win/lose count 6.0/3.0 (3.0)
# Epoch 057/060 | Loss 0.0018 | Win/lose count 12.0/3.0 (9.0)
# Epoch 058/060 | Loss 0.0027 | Win/lose count 6.0/1.0 (5.0)
# Epoch 059/060 | Loss 0.0056 | Win/lose count 9.0/3.0 (6.0)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 8__ Implement the DQN training algorithm using a CNN (for example, 2 convolutional layers and one final fully connected layer).

# %%
class DQN_CNN(DQN):
    def __init__(self, *args,lr=0.1,**kwargs):
        super(DQN_CNN, self).__init__(*args,**kwargs)
        model = Sequential()        
        model.add(Conv2D(16, (3,3), input_shape=(5,5,self.n_state), activation="relu"))
        model.add(Conv2D(32, (2,2), activation="relu"))
        model.add(Flatten())
        model.add(Dense(4))
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent,env,epochs_train,prefix='cnn_train')
HTML(display_videos('cnn_train50.mp4'))
# Out:
# Epoch 000/060 | Loss 0.0074 | Win/lose count 6.0/4.0 (2.0)
# Epoch 001/060 | Loss 0.0026 | Win/lose count 1.0/1.0 (0.0)
# Epoch 002/060 | Loss 0.0081 | Win/lose count 2.0/6.0 (-4.0)
# Epoch 003/060 | Loss 0.0077 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 004/060 | Loss 0.0027 | Win/lose count 3.0/2.0 (1.0)
# Epoch 005/060 | Loss 0.0148 | Win/lose count 3.0/2.0 (1.0)
# Epoch 006/060 | Loss 0.0040 | Win/lose count 5.0/4.0 (1.0)
# Epoch 007/060 | Loss 0.0010 | Win/lose count 6.5/2.0 (4.5)
# Epoch 008/060 | Loss 0.0062 | Win/lose count 2.0/2.0 (0.0)
# Epoch 009/060 | Loss 0.0021 | Win/lose count 0.5/1.0 (-0.5)
# Epoch 010/060 | Loss 0.0582 | Win/lose count 3.0/3.0 (0.0)
# Epoch 011/060 | Loss 0.0010 | Win/lose count 6.5/2.0 (4.5)
# Epoch 012/060 | Loss 0.0070 | Win/lose count 3.5/8.0 (-4.5)
# Epoch 013/060 | Loss 0.0581 | Win/lose count 4.5/2.0 (2.5)
# Epoch 014/060 | Loss 0.0031 | Win/lose count 4.5/3.0 (1.5)
# Epoch 015/060 | Loss 0.0010 | Win/lose count 2.5/1.0 (1.5)
# Epoch 016/060 | Loss 0.0023 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 017/060 | Loss 0.0015 | Win/lose count 3.5/2.0 (1.5)
# Epoch 018/060 | Loss 0.0022 | Win/lose count 15.0/1.0 (14.0)
# Epoch 019/060 | Loss 0.0061 | Win/lose count 11.0/1.0 (10.0)
# Epoch 020/060 | Loss 0.0025 | Win/lose count 12.5/2.0 (10.5)
# Epoch 021/060 | Loss 0.0075 | Win/lose count 6.5/2.0 (4.5)
# Epoch 022/060 | Loss 0.0069 | Win/lose count 7.5/4.0 (3.5)
# Epoch 023/060 | Loss 0.0029 | Win/lose count 4.5/1.0 (3.5)
# Epoch 024/060 | Loss 0.0025 | Win/lose count 16.0/2.0 (14.0)
# Epoch 025/060 | Loss 0.0016 | Win/lose count 7.0/1.0 (6.0)
# Epoch 026/060 | Loss 0.0031 | Win/lose count 9.0/3.0 (6.0)
# Epoch 027/060 | Loss 0.0030 | Win/lose count 9.5/2.0 (7.5)
# Epoch 028/060 | Loss 0.0038 | Win/lose count 9.5/3.0 (6.5)
# Epoch 029/060 | Loss 0.0028 | Win/lose count 16.5/4.0 (12.5)
# Epoch 030/060 | Loss 0.0012 | Win/lose count 8.0/0 (8.0)
# Epoch 031/060 | Loss 0.0027 | Win/lose count 13.0/2.0 (11.0)
# Epoch 032/060 | Loss 0.0049 | Win/lose count 17.0/3.0 (14.0)
# Epoch 033/060 | Loss 0.1372 | Win/lose count 9.0/1.0 (8.0)
# Epoch 034/060 | Loss 0.0039 | Win/lose count 11.5/0 (11.5)
# Epoch 035/060 | Loss 0.0046 | Win/lose count 12.5/1.0 (11.5)
# Epoch 036/060 | Loss 0.0404 | Win/lose count 19.5/1.0 (18.5)
# Epoch 037/060 | Loss 0.0097 | Win/lose count 5.5/2.0 (3.5)
# Epoch 038/060 | Loss 0.0027 | Win/lose count 15.0/4.0 (11.0)
# Epoch 039/060 | Loss 0.0021 | Win/lose count 15.5/2.0 (13.5)
# Epoch 040/060 | Loss 0.0016 | Win/lose count 16.5/3.0 (13.5)
# Epoch 041/060 | Loss 0.0533 | Win/lose count 13.5/5.0 (8.5)
# Epoch 042/060 | Loss 0.0013 | Win/lose count 7.0/2.0 (5.0)
# Epoch 043/060 | Loss 0.0022 | Win/lose count 5.0/2.0 (3.0)
# Epoch 044/060 | Loss 0.0044 | Win/lose count 6.5/1.0 (5.5)
# Epoch 045/060 | Loss 0.0525 | Win/lose count 8.5/1.0 (7.5)
# Epoch 046/060 | Loss 0.0016 | Win/lose count 4.0/1.0 (3.0)
# Epoch 047/060 | Loss 0.0015 | Win/lose count 6.0/4.0 (2.0)
# Epoch 048/060 | Loss 0.0032 | Win/lose count 14.0/1.0 (13.0)
# Epoch 049/060 | Loss 0.0028 | Win/lose count 7.0/2.0 (5.0)
# Epoch 050/060 | Loss 0.0037 | Win/lose count 16.5/2.0 (14.5)
# Epoch 051/060 | Loss 0.0028 | Win/lose count 19.0/5.0 (14.0)
# Epoch 052/060 | Loss 0.0499 | Win/lose count 13.0/3.0 (10.0)
# Epoch 053/060 | Loss 0.0021 | Win/lose count 16.0/2.0 (14.0)
# Epoch 054/060 | Loss 0.0036 | Win/lose count 18.0/2.0 (16.0)
# Epoch 055/060 | Loss 0.0034 | Win/lose count 21.0/5.0 (16.0)
# Epoch 056/060 | Loss 0.0029 | Win/lose count 19.0/2.0 (17.0)
# Epoch 057/060 | Loss 0.0031 | Win/lose count 13.5/2.0 (11.5)
# Epoch 058/060 | Loss 0.0034 | Win/lose count 8.5/2.0 (6.5)
# Epoch 059/060 | Loss 0.0020 | Win/lose count 12.5/1.0 (11.5)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 9__ Test both algorithms and compare their performances. Which issue(s) do you observe? Observe also different behaviors by changing the temperature.

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.3)
agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# Test of the CNN
# Win/lose count 7.5/3.0. Average score (4.5)
# Win/lose count 4.0/1.0. Average score (3.75)
# Win/lose count 13.0/2.0. Average score (6.166666666666667)
# Win/lose count 5.5/0. Average score (6.0)
# Win/lose count 5.5/1.0. Average score (5.7)
# Win/lose count 9.5/2.0. Average score (6.0)
# Win/lose count 8.5/5.0. Average score (5.642857142857143)
# Win/lose count 3.0/2.0. Average score (5.0625)
# Win/lose count 3.5/3.0. Average score (4.555555555555555)
# Win/lose count 7.5/3.0. Average score (4.55)
# Win/lose count 1.5/2.0. Average score (4.090909090909091)
# Win/lose count 6.5/3.0. Average score (4.041666666666667)
# Win/lose count 4.0/2.0. Average score (3.8846153846153846)
# Win/lose count 6.5/3.0. Average score (3.857142857142857)
# Win/lose count 2.5/1.0. Average score (3.7)
# Win/lose count 3.0/2.0. Average score (3.53125)
# Win/lose count 5.0/1.0. Average score (3.5588235294117645)
# Win/lose count 9.0/3.0. Average score (3.6944444444444446)
# Win/lose count 13.0/2.0. Average score (4.078947368421052)
# Win/lose count 11.5/3.0. Average score (4.3)
# Final score: 4.3
# Test of the FC
# Win/lose count 3.5/4.0. Average score (-0.5)
# Win/lose count 4.5/4.0. Average score (0.0)
# Win/lose count 2.5/6.0. Average score (-1.1666666666666667)
# Win/lose count 4.5/5.0. Average score (-1.0)
# Win/lose count 4.0/6.0. Average score (-1.2)
# Win/lose count 6.0/4.0. Average score (-0.6666666666666666)
# Win/lose count 3.0/6.0. Average score (-1.0)
# Win/lose count 1.5/4.0. Average score (-1.1875)
# Win/lose count 4.5/4.0. Average score (-1.0)
# Win/lose count 2.5/1.0. Average score (-0.75)
# Win/lose count 4.0/9.0. Average score (-1.1363636363636365)
# Win/lose count 2.0/4.0. Average score (-1.2083333333333333)
# Win/lose count 3.5/2.0. Average score (-1.0)
# Win/lose count 2.0/5.0. Average score (-1.1428571428571428)
# Win/lose count 3.5/3.0. Average score (-1.0333333333333334)
# Win/lose count 2.5/3.0. Average score (-1.0)
# Win/lose count 1.0/5.0. Average score (-1.1764705882352942)
# Win/lose count 1.5/2.0. Average score (-1.1388888888888888)
# Win/lose count 4.0/4.0. Average score (-1.0789473684210527)
# Win/lose count 2.0/7.0. Average score (-1.275)
# Final score: -1.275

# %%
HTML(display_videos('cnn_test19.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
HTML(display_videos('fc_test19.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# We notice that the agent tends to not explore the map well and gets stuck in a position especially for the agent with the fully connected network. If we increase the temperature we have more positive rewards cells. This helps the agent explore the map more as there are more reward cells in his visibility range. Thus, we get a higher score.

# %% [markdown]
# ***
#
# The algorithm tends to not explore the map which can be an issue. We propose two ideas in order to encourage exploration:
# 1. Incorporating a decreasing $\epsilon$-greedy exploration. You can use the method ```set_epsilon```
# 2. Append via the environment a new state that describes if a cell has been visited or not
#
# ***
# __Question 10__ Design a new ```train_explore``` function and environment class ```EnvironmentExploring``` to tackle the issue of exploration.

# %%
def train_explore(agent, env, epoch, prefix=''):
    # Number of won games
    score = 0
    loss = 0
    epsilon_start = agent.epsilon
    last_epsilon = 0.1
    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0
        agent.set_epsilon(epsilon_start - e * (epsilon_start - last_epsilon) / epoch)
        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action, train=True)
            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')
        
class EnvironmentExploring(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))
        self.malus_position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action, train=False):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')
        
        self.t = self.t + 1
        reward = self.board[self.x, self.y] 
        if train:
            reward -= self.malus_position[self.x, self.y]
        
        self.malus_position[self.x, self.y] = 0.1 

        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                self.board.reshape(self.grid_size, self.grid_size,1),
                                self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)
        
        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                self.board.reshape(self.grid_size, self.grid_size,1),
                                self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %%
# Training
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32,n_state=3)
train_explore(agent, env, epochs_train, prefix='cnn_train_explore')
HTML(display_videos('cnn_train_explore10.mp4'))
# Out:
# Epoch 000/060 | Loss 0.0134 | Win/lose count 6.0/25.400000000000098 (-19.400000000000098)
# Epoch 001/060 | Loss 0.0068 | Win/lose count 4.0/23.300000000000026 (-19.300000000000026)
# Epoch 002/060 | Loss 0.0021 | Win/lose count 3.9/18.19999999999999 (-14.299999999999988)
# Epoch 003/060 | Loss 0.0061 | Win/lose count 3.0999999999999996/22.50000000000006 (-19.400000000000063)
# Epoch 004/060 | Loss 0.0081 | Win/lose count 10.800000000000002/19.400000000000013 (-8.60000000000001)
# Epoch 005/060 | Loss 0.0022 | Win/lose count 7.900000000000002/18.900000000000002 (-11.0)
# Epoch 006/060 | Loss 0.0037 | Win/lose count 2.9/19.0 (-16.1)
# Epoch 007/060 | Loss 0.0045 | Win/lose count 11.400000000000006/19.900000000000016 (-8.50000000000001)
# Epoch 008/060 | Loss 0.0039 | Win/lose count 19.4/15.799999999999963 (3.600000000000035)
# Epoch 009/060 | Loss 0.0071 | Win/lose count 12.200000000000006/22.900000000000077 (-10.70000000000007)
# Epoch 010/060 | Loss 0.0055 | Win/lose count 3.5999999999999996/22.200000000000053 (-18.60000000000005)
# Epoch 011/060 | Loss 0.0031 | Win/lose count 11.900000000000006/21.200000000000042 (-9.300000000000036)
# Epoch 012/060 | Loss 0.0042 | Win/lose count 4.3999999999999995/20.000000000000018 (-15.60000000000002)
# Epoch 013/060 | Loss 0.0070 | Win/lose count 9.200000000000003/24.800000000000086 (-15.600000000000083)
# Epoch 014/060 | Loss 0.0111 | Win/lose count 3.5999999999999996/21.000000000000014 (-17.400000000000013)
# Epoch 015/060 | Loss 0.0063 | Win/lose count 14.000000000000007/20.50000000000003 (-6.500000000000021)
# Epoch 016/060 | Loss 0.0101 | Win/lose count 9.200000000000003/17.799999999999983 (-8.59999999999998)
# Epoch 017/060 | Loss 0.0070 | Win/lose count 17.900000000000002/16.69999999999997 (1.2000000000000313)
# Epoch 018/060 | Loss 0.0101 | Win/lose count 10.100000000000003/22.600000000000044 (-12.50000000000004)
# Epoch 019/060 | Loss 0.0038 | Win/lose count 4.8/21.900000000000052 (-17.10000000000005)
# Epoch 020/060 | Loss 0.0024 | Win/lose count 12.800000000000006/19.90000000000002 (-7.100000000000014)
# Epoch 021/060 | Loss 0.0077 | Win/lose count 6.400000000000001/21.50000000000004 (-15.100000000000037)
# Epoch 022/060 | Loss 0.0036 | Win/lose count 11.700000000000005/19.20000000000001 (-7.500000000000005)
# Epoch 023/060 | Loss 0.0058 | Win/lose count 9.200000000000003/19.800000000000015 (-10.600000000000012)
# Epoch 024/060 | Loss 0.0076 | Win/lose count 12.000000000000005/22.100000000000055 (-10.10000000000005)
# Epoch 025/060 | Loss 0.0042 | Win/lose count 11.600000000000005/18.199999999999992 (-6.599999999999987)
# Epoch 026/060 | Loss 0.0039 | Win/lose count 9.200000000000003/17.799999999999983 (-8.59999999999998)
# Epoch 027/060 | Loss 0.0052 | Win/lose count 12.800000000000006/19.90000000000002 (-7.100000000000014)
# Epoch 028/060 | Loss 0.0069 | Win/lose count 10.800000000000004/19.40000000000001 (-8.600000000000005)
# Epoch 029/060 | Loss 0.0049 | Win/lose count 12.400000000000006/21.000000000000025 (-8.60000000000002)
# Epoch 030/060 | Loss 0.0091 | Win/lose count 14.400000000000007/19.499999999999996 (-5.099999999999989)
# Epoch 031/060 | Loss 0.0104 | Win/lose count 16.000000000000007/16.09999999999996 (-0.09999999999995168)
# Epoch 032/060 | Loss 0.0154 | Win/lose count 14.400000000000007/17.499999999999982 (-3.0999999999999748)
# Epoch 033/060 | Loss 0.0167 | Win/lose count 10.000000000000004/19.599999999999998 (-9.599999999999994)
# Epoch 034/060 | Loss 0.0075 | Win/lose count 12.800000000000006/21.9 (-9.099999999999993)
# Epoch 035/060 | Loss 0.0136 | Win/lose count 2.4/20.50000000000002 (-18.100000000000023)
# Epoch 036/060 | Loss 0.0096 | Win/lose count 10.000000000000004/19.600000000000012 (-9.600000000000009)
# Epoch 037/060 | Loss 0.0173 | Win/lose count 16.800000000000004/19.90000000000001 (-3.100000000000005)
# Epoch 038/060 | Loss 0.0286 | Win/lose count 12.800000000000006/17.899999999999988 (-5.099999999999982)
# Epoch 039/060 | Loss 0.0124 | Win/lose count 15.600000000000009/19.200000000000006 (-3.599999999999998)
# Epoch 040/060 | Loss 0.0079 | Win/lose count 16.400000000000006/16.99999999999997 (-0.5999999999999659)
# Epoch 041/060 | Loss 0.0258 | Win/lose count 10.400000000000004/21.50000000000003 (-11.100000000000025)
# Epoch 042/060 | Loss 0.0307 | Win/lose count 10.400000000000004/19.499999999999996 (-9.099999999999993)
# Epoch 043/060 | Loss 0.0081 | Win/lose count 13.600000000000007/19.70000000000002 (-6.100000000000014)
# Epoch 044/060 | Loss 0.0139 | Win/lose count 12.000000000000005/20.100000000000023 (-8.100000000000017)
# Epoch 045/060 | Loss 0.0051 | Win/lose count 18.0/18.6 (-0.6000000000000014)
# Epoch 046/060 | Loss 0.0104 | Win/lose count 17.6/16.69999999999997 (0.9000000000000306)
# Epoch 047/060 | Loss 0.0174 | Win/lose count 8.400000000000002/20.000000000000018 (-11.600000000000016)
# Epoch 048/060 | Loss 0.0194 | Win/lose count 14.000000000000007/19.60000000000002 (-5.600000000000012)
# Epoch 049/060 | Loss 0.0187 | Win/lose count 6.000000000000001/21.600000000000012 (-15.600000000000012)
# Epoch 050/060 | Loss 0.0089 | Win/lose count 8.400000000000002/19.000000000000004 (-10.600000000000001)
# Epoch 051/060 | Loss 0.0155 | Win/lose count 14.000000000000007/21.600000000000044 (-7.600000000000037)
# Epoch 052/060 | Loss 0.0072 | Win/lose count 19.999999999999993/17.09999999999998 (2.900000000000013)
# Epoch 053/060 | Loss 0.0327 | Win/lose count 14.400000000000007/21.500000000000032 (-7.1000000000000245)
# Epoch 054/060 | Loss 0.0137 | Win/lose count 15.600000000000009/20.200000000000028 (-4.600000000000019)
# Epoch 055/060 | Loss 0.0144 | Win/lose count 14.800000000000008/20.400000000000027 (-5.600000000000019)
# Epoch 056/060 | Loss 0.0134 | Win/lose count 21.19999999999999/18.800000000000004 (2.3999999999999844)
# Epoch 057/060 | Loss 0.0459 | Win/lose count 14.800000000000008/18.399999999999995 (-3.599999999999987)
# Epoch 058/060 | Loss 0.0188 | Win/lose count 16.000000000000007/19.100000000000012 (-3.100000000000005)
# Epoch 059/060 | Loss 0.0148 | Win/lose count 15.200000000000008/17.29999999999998 (-2.0999999999999712)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# Evaluation
test(agent,env,epochs_test,prefix='cnn_test_explore')
HTML(display_videos('cnn_test_explore10.mp4'))
# Out:
# Win/lose count 20.5/4.0. Average score (16.5)
# Win/lose count 11.5/1.0. Average score (13.5)
# Win/lose count 18.0/1.0. Average score (14.666666666666666)
# Win/lose count 13.0/4.0. Average score (13.25)
# Win/lose count 8.5/1.0. Average score (12.1)
# Win/lose count 18.0/4.0. Average score (12.416666666666666)
# Win/lose count 7.0/2.0. Average score (11.357142857142858)
# Win/lose count 18.0/1.0. Average score (12.0625)
# Win/lose count 14.0/3.0. Average score (11.944444444444445)
# Win/lose count 15.5/2.0. Average score (12.1)
# Win/lose count 14.0/2.0. Average score (12.090909090909092)
# Win/lose count 10.0/1.0. Average score (11.833333333333334)
# Win/lose count 7.5/1.0. Average score (11.423076923076923)
# Win/lose count 11.0/4.0. Average score (11.107142857142858)
# Win/lose count 12.5/4.0. Average score (10.933333333333334)
# Win/lose count 15.0/2.0. Average score (11.0625)
# Win/lose count 7.5/1.0. Average score (10.794117647058824)
# Win/lose count 11.5/1.0. Average score (10.777777777777779)
# Win/lose count 12.0/2.0. Average score (10.736842105263158)
# Win/lose count 18.0/1.0. Average score (11.05)
# Final score: 11.05
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __BONUS question__ Use the expert DQN from the previous question to generate some winning games. Train a model that mimicks its behavior. Compare the performances.

# %% [markdown]
# ***
